# %% [markdown]
# # What is a Jupyter notebook?

# %% [markdown]
# > And why are they important?

# %%
import skimage as sk 
import numpy as np 
import matplotlib.pyplot as plt

# %%
skin_image = sk.data.skin()
# Out:
# Downloading file 'data/skin.jpg' from 'https://gitlab.com/scikit-image/data/-/raw/master/Normal_Epidermis_and_Dermis_with_Intradermal_Nevus_10x.JPG' to '/home/frank/.cache/scikit-image/0.18.1'.

# %%
fig, ax = plt.subplots()
ax.imshow(skin_image)
